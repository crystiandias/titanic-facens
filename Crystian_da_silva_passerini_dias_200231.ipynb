# %% [markdown]
# # **Trabalho Final**
# ### Algoritmos e Programação com Linguagem Python
# ---
#
# **Orientações Gerais:**
#
# * Esta é o trabalho final prático onde serão trabalhados conceitos
# apresentados e exercitados em sala de aula.
#
# * Aspéctos como clareza e organização do código, comentários, raciocínio lógico, coerência no nome de variáveis, utilização das estruturas mais adequadas para a solução dos problemas e o funcionamento adequado serão analisados e irão compor o valor da nota final.
#
# * Procure entender exatamente o que se pede antes de iniciar a codificação. Quando se sabe o que é necessário fazer, a codificação fica mais fácil, mais eficiente e mais divertida ;-).
#
# * Faça o upload do notebook completo nomeado da seguinte forma: *nome_sobrenome_RA.ipynb*.
#
# * No caso de grupos, informar ao professor os membros de cada grupo e cada um deverá importar o arquivo no Canvas individualmente.
#
# * Arquivos com nomes incorretos serão desconsiderados!
#
# * Não deixem dúvidas para trás! Acessem os grupos combinados ou entrem em contato com o professor.
#
# ✌ Sucesso o/

# %% [markdown]
# # RMS Titanic
#
# O RMS Titanic foi um navio de passageiros britânico operado pela White Star Line e construído pelos estaleiros da Harland and Wolff em Belfast. Foi a segunda embarcação da Classe Olympic de transatlânticos depois do RMS Olympic e seguido pelo HMHS Britannic. Projetado pelos engenheiros navais Alexander Carlisle e Thomas Andrews, sua construção começou em março de 1909 e ele foi lançado ao mar em maio de 1911. O Titanic foi pensado para ser o navio mais luxuoso e mais seguro de sua época, gerando lendas que era supostamente "inafundável".
#
# A embarcação partiu em sua viagem inaugural de Southampton para Nova Iorque em 10 de abril de 1912, no caminho passando em Cherbourg-Octeville na França e por Queenstown na Irlanda. Ele colidiu com um iceberg às 23h40min do dia 14 de abril e afundou na madrugada do dia seguinte matando mais de 1500 pessoas, sendo um dos maiores desastres marítimos em tempos de paz de toda a história. Seu naufrágio destacou vários pontos fracos de seu projeto, deficiências nos procedimentos de evacuação de emergência e falhas nas regulamentações marítimas da época. Comissões de inquérito foram instauradas nos Estados Unidos e no Reino Unido, levando a mudanças nas leis internacionais de navegação que permanecem em vigor mais de um século depois.
#
# Os destroços do Titanic foram procurados por décadas até serem encontrados em 1985 por uma equipe liderada por Robert Ballard. Ele se encontra a 3843 m de profundidade e a 650 km ao sudeste de Terra Nova no Canadá. Sua história e naufrágio permaneceram no imaginário popular durante décadas, levando a produção de vários livros e filmes a seu respeito, mais notavelmente o filme Titanic de 1997. Até hoje o Titanic permanece como um dos navios mais famosos da história, com seus destroços atraindo várias expedições de exploração ao longo dos anos.
#
# *Fonte:* [WikiPedia](https://pt.wikipedia.org/wiki/RMS_Titanic)
#
# --------

# %% [markdown]
# A equipe da [Udacity](https://udacity.com) disponibilizou informações sobre uma parte dos passageiros à bordo do RMS Titanic no dia daquela tragédia. Esse _dataset_ que contém informações reais vem sendo utilizado em diversos estudos de caso, além de servir de base para aprendizado de Ciência de Dados, Estatística e Machine Learning.
#
# O arquivo **titanic_data.csv** contém informações reais sobre os passageiros organizadas da seguinte forma:
#
# - Survived (Sobreviveu): 0 = Não, 1 = Sim
# - Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
# - Sex (Sexo): Sexo do passageiro
# - Age (Idade): Idade em anos
# - Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
# - Parch: Quantidade de pais / crianças a bordo do Titanic
# - Ticket (Bilhete): Número do bilhete de embarque
# - Fare (Tarifa): Tarifa paga pelo Passageiro
# - Cabin (Cabine): Número de cabine
# - Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# O objetivo deste estudo é obter algumas informações estatísticas sobre a tragédia e realizar alguns _insights_ a respeito dos tripulantes e das circunstâncias do acidente.
#
# Efetue a carga do arquivo através da biblioteca _Pandas_ e a partir do _DataFrame_ gerado, efetue as operações necessárias para responder as questões.

# %% [markdown]
# ## Importando o DataSet

# %% [markdown]
# 1 - Efetuar a leitura do dataset através do Pandas, gerando um DataFrame de nome tit, levando-se em consideração que o arquivo encontra-se na mesma pasta do notebook.

# %%
import numpy as np
import pandas as pd
import sys
import matplotlib as mpl
import matplotlib.pyplot as plt

tit = pd.read_csv('/content/titanic_data.csv')

# %% [markdown]
# ## Conhecendo o DataSet

# %% [markdown]
# 2 - Quantas linhas e colunas tem o dataset? Quais os tipos das colunas?

# %%
print(f"as linhas e colunas sao {tit.shape}")
# Out:
# as linhas e colunas sao (891, 12)

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 3 - Mostre os dados dos dez primeiros e 8 últimos registros do dataset.

# %%
tit.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
tit.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5            382652  29.125   NaN        Q
# 886    male  27.0      0      0            211536  13.000   NaN        S
# 887  female  19.0      0      0            112053  30.000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0            111369  30.000  C148        C
# 890    male  32.0      0      0            370376   7.750   NaN        Q

# %% [markdown]
# 4 - Cálculos envolvendo colunas numéricas com dados faltantes podem sofrer impacto. É possível afirmar se há dados faltantes no dataset? Caso positivo, quais e quantos seriam esses dados? Preencha os dados faltantes de forma que não influenciem em operações futuras.

# %%
tit.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.title('Relação entre dados faltantes')
tit.isna().sum().plot(kind="bar")
# Out:
# <Axes: title={'center': 'Relação entre dados faltantes'}>

# %%
tit.dropna()
idade=tit[(tit['Age'] > 0)]
tit=tit.fillna(round(idade['Age'].mean(),0))

# %%
tit.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Adequando o DataSet

# %% [markdown]
# 5 - Uma vez que algumas colunas não serão utilizadas, eventualmente é melhor excluí-las para que não interfiram na análise. Assim, exclua do dataset as colunas Sibsp, Parch e Ticket.

# %%
tit=tit.drop(["SibSp","Parch","Ticket"], axis='columns')

# %%
tit.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#   Cabin Embarked
# 0  30.0        S
# 1   C85        C
# 2  30.0        S
# 3  C123        S
# 4  30.0        S

# %% [markdown]
# 6 - Renomear as colunas restantes para a lingua portuguesa, utilizando os seguintes nomes de colunas: IdPassageiro, Sobreviveu, Classe, Nome, Sexo, Idade, Tarifa, Cabine e Embarque.

# %%
tit = tit.rename(columns={'PassengerId':'IdPassageiro', 'Survived': 'Sobreviveu', 'Pclass': 'Classe', 'Name': 'Nome',\
                          'Sex': 'Sexo', 'Age': 'Idade', 'Fare': 'Tarifa', 'Cabin': 'Cabine', 'Embarked': 'Embarque'})
tit.head(5)
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade   Tarifa  \
# 0                            Braund, Mr. Owen Harris    male   22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female   26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0  53.1000
# 4                           Allen, Mr. William Henry    male   35.0   8.0500
#
#   Cabine Embarque
# 0   30.0        S
# 1    C85        C
# 2   30.0        S
# 3   C123        S
# 4   30.0        S

# %% [markdown]
# 7 - Alterar o conteudo da coluna Sobreviveu para:
# - 0 => Não
# - 1 => Sim

# %%
tit.loc[tit.Sobreviveu==0,'Sobreviveu']='Não'

tit.loc[tit.Sobreviveu==1,'Sobreviveu']='Sim'

# %%
tit.head(5)
# Out:
#    IdPassageiro Sobreviveu  Classe  \
# 0             1        Não       3
# 1             2        Sim       1
# 2             3        Sim       3
# 3             4        Sim       1
# 4             5        Não       3
#
#                                                 Nome    Sexo  Idade   Tarifa  \
# 0                            Braund, Mr. Owen Harris    male   22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female   26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0  53.1000
# 4                           Allen, Mr. William Henry    male   35.0   8.0500
#
#   Cabine Embarque
# 0   30.0        S
# 1    C85        C
# 2   30.0        S
# 3   C123        S
# 4   30.0        S

# %% [markdown]
# 8 - Alterar o conteudo da coluna Sexo para:
# - female => Mulher
# - male   => Homem

# %%
tit.loc[tit.Sexo=="female",'Sexo']='Mulher'

tit.loc[tit.Sexo=="male",'Sexo']='Homem'

# %%
tit.head(5)
# Out:
#    IdPassageiro Sobreviveu  Classe  \
# 0             1        Não       3
# 1             2        Sim       1
# 2             3        Sim       3
# 3             4        Sim       1
# 4             5        Não       3
#
#                                                 Nome    Sexo  Idade   Tarifa  \
# 0                            Braund, Mr. Owen Harris   Homem   22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Mulher   38.0  71.2833
# 2                             Heikkinen, Miss. Laina  Mulher   26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Mulher   35.0  53.1000
# 4                           Allen, Mr. William Henry   Homem   35.0   8.0500
#
#   Cabine Embarque
# 0   30.0        S
# 1    C85        C
# 2   30.0        S
# 3   C123        S
# 4   30.0        S

# %% [markdown]
# ## Alguns números

# %% [markdown]
# 9 - Quantas mulheres e quantos homems estavam à bordo, de acordo com o dataset?

# %%
tit[['Sexo']].value_counts()
# Out:
# Sexo
# Homem     577
# Mulher    314
# dtype: int64

# %%
plt.title('Passageiros por genero')
tit[['Sexo']].value_counts().plot(kind="bar").set_ylim(0, len(tit))
# Out:
# (0.0, 891.0)

# %% [markdown]
# 10 - Quantos passageiros sobreviveram e quantos não sobreviveram?

# %%
tit[['Sobreviveu']].value_counts()
# Out:
# Sobreviveu
# Não           549
# Sim           342
# dtype: int64

# %%
plt.title('Relação entre sobreviventes e não sobreviventes')
tit[['Sobreviveu']].value_counts().plot(kind="bar").set_ylim(0, len(tit))
# Out:
# (0.0, 891.0)

# %% [markdown]
# 11 - Quantas mulheres não sobreviveram?

# %%
total_mulheres=tit[tit['Sexo'] == 'Mulher']
mulher_naosobreviveu=total_mulheres[total_mulheres['Sobreviveu'] == 'Não']
mulher_sobreviveu=total_mulheres[total_mulheres['Sobreviveu'] == 'Sim']
mulher_naosobreviveu[['Sobreviveu','Sexo']].value_counts()
# Out:
# Sobreviveu  Sexo
# Não         Mulher    81
# dtype: int64

# %%
fig, ax_dict = plt.subplot_mosaic([['top'],],empty_sentinel="BLANK")
ax_dict['top'].set_title('Relação entre as mulheres que\n não sobreviveram, sobreviveram e total')
ax_dict['top'].bar(mulher_naosobreviveu['Sobreviveu'],mulher_naosobreviveu['Sexo'].value_counts())
ax_dict['top'].bar(mulher_sobreviveu['Sobreviveu'],mulher_sobreviveu['Sexo'].value_counts())
ax_dict['top'].bar(total_mulheres['Sexo'],total_mulheres['Sexo'].value_counts())
# Out:
# <BarContainer object of 314 artists>

# %% [markdown]
# 12 - Proporcionalmente, sobreviveram mais homens ou mais mulheres? Cite as proporções.

# %%
total_homens=tit[tit['Sexo'] == 'Homem']
homem_naosobreviveu=total_homens[total_homens['Sobreviveu'] == 'Não']
homem_sobreviveu=total_homens[total_homens['Sobreviveu'] == 'Sim']
homem_sobreviveu[['Sobreviveu','Sexo']].value_counts()
homem_naosobreviveu[['Sobreviveu','Sexo']].value_counts()
# Out:
# Sobreviveu  Sexo
# Não         Homem    468
# dtype: int64

# %%
fig, ax_dict = plt.subplot_mosaic([['top','top2'],],empty_sentinel="BLANK")

ax_dict['top'].set_title('Mulheres - Sobreviventes\n e Não sobreviventes ')
ax_dict['top'].bar(mulher_naosobreviveu['Sobreviveu'],mulher_naosobreviveu['Sexo'].value_counts())
ax_dict['top'].bar(mulher_sobreviveu['Sobreviveu'],mulher_sobreviveu['Sexo'].value_counts())
ax_dict['top'].bar(total_mulheres['Sexo'],total_mulheres['Sexo'].value_counts())
ax_dict['top'].set_ylim(0, len(tit))

ax_dict['top2'].set_title('Homem - Sobreviventes\n e Não sobreviventes')
ax_dict['top2'].bar(homem_naosobreviveu['Sobreviveu'],homem_naosobreviveu['Sexo'].value_counts())
ax_dict['top2'].bar(homem_sobreviveu['Sobreviveu'],homem_sobreviveu['Sexo'].value_counts())
ax_dict['top2'].bar(total_homens['Sexo'],total_homens['Sexo'].value_counts())
ax_dict['top2'].set_ylim(0, len(tit))
# Out:
# (0.0, 891.0)

# %%
total = len(mulher_sobreviveu)+len(homem_sobreviveu)
print("O total de sobreviventes ",total)

porcent_man = (len(homem_sobreviveu)*100)/total
porcent_woman = (len(mulher_sobreviveu)*100)/total
print("A Porcentagem de Homens sobreviventes ",porcent_man)
print("A Porcentagem de Mulheres sobreviventes ",porcent_woman)
# Out:
# O total de sobreviventes  342
# A Porcentagem de Homens sobreviventes  31.871345029239766
# A Porcentagem de Mulheres sobreviventes  68.12865497076024

# %%
titulo = 'Homem','Mulher'
sizes = [porcent_man, porcent_woman]

fig, ax = plt.subplots()

ax.set_title('Porcentagem de\n sobreviventes\n por gênero')
ax.pie(sizes, labels=titulo)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f60ce420ca0>,
#   <matplotlib.patches.Wedge at 0x7f60ce3fbe80>],
#  [Text(0.5931585112380521, 0.9263708655532393, 'Homem'),
#   Text(-0.5931584245049494, -0.9263709210887432, 'Mulher')])

# %% [markdown]
# 13 - Levando-se em consideração a idade dos passageiros, qual a idade e quantidade de pessoas com o maior número de mortos?

# %%
nao_sobreviventes=tit[(tit['Sobreviveu'] == 'Não')]
nao_sobreviventes.groupby("Sobreviveu")["Idade"].value_counts().sort_values(ascending = False).head(1)
# Out:
# Sobreviveu  Idade
# Não         30.0     140
# Name: Idade, dtype: int64

# %%
plt.ylabel('Quantidade de Mortos')
plt.title('Maior número de mortos por Idade "8 maiores valores"')
nao_sobreviventes.groupby("Sobreviveu")["Idade"].value_counts().sort_values(ascending = False).head(8).plot(kind="bar")
# Out:
# <Axes: title={'center': 'Maior número de mortos por Idade "8 maiores valores"'}, xlabel='Sobreviveu,Idade', ylabel='Quantidade de Mortos'>

# %% [markdown]
# 14 - Qual a média de idade dos homens sobreviventes?

# %%
homem_sobreviveu["Idade"].mean()
# Out:
# 27.675871559633027

# %%
plt.title('Mediana de homens sobreviventes por Idade')
homem_sobreviveu.groupby("Sobreviveu")["Idade"].value_counts().sort_values(ascending = False).head(8).plot(kind="bar")
# Out:
# <Axes: title={'center': 'Mediana de homens sobreviventes por Idade'}, xlabel='Sobreviveu,Idade'>

# %% [markdown]
# 15 - Levando-se em consideração passageiros prioritários (mulheres e crianças de até 15 anos independente do sexo) qual a proporção de sobreviventes por sexo?

# %%
#mulher_sobreviveu
#homem_naosobreviveu=tit[(tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Homem')]
prioritarios=tit[((tit['Idade'] <=15) | (tit['Sexo'] == 'Mulher')) & (tit['Sobreviveu'] == 'Sim')]

prioritarios_mulher_total = prioritarios[(prioritarios['Sexo'] == 'Mulher')]["IdPassageiro"].count()

prioritarios_homem_total = prioritarios[(prioritarios['Sexo'] == 'Homem')]["IdPassageiro"].count()



print(f' % Mulher: {(prioritarios_mulher_total*100)/len(prioritarios)}\
      \n % Homem: {(prioritarios_homem_total*100)/len(prioritarios)} ')
# Out:
#  % Mulher: 91.73228346456693
#  % Homem: 8.26771653543307

# %%
labels = 'Mulher', 'Homem'
sizes = [prioritarios_mulher_total, prioritarios_homem_total]

fig, ax = plt.subplots()
ax.set_title('Porcentagem de\n sobreviventes\n prioritários\n por gênero')
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f60cedd54b0>,
#   <matplotlib.patches.Wedge at 0x7f60cd8b85e0>],
#  [Text(-1.0631030191444317, 0.2825101249265133, 'Mulher'),
#   Text(1.063102999306549, -0.28251019957767853, 'Homem')])

# %% [markdown]
# 16 - Qual a quantidade de passageiros por classe?

# %%
tit.groupby("Classe")["IdPassageiro"].count().sort_values(ascending = False)
# Out:
# Classe
# 3    491
# 1    216
# 2    184
# Name: IdPassageiro, dtype: int64

# %%
plt.title('Quantidade de sobreviventes por classes')
tit.groupby("Classe")["IdPassageiro"].count().sort_values().plot(kind="bar")
# Out:
# <Axes: title={'center': 'Quantidade de sobreviventes por classes'}, xlabel='Classe'>

# %% [markdown]
# 17 - Qual o percentual de sobreviventes por classe?

# %%
sobreviventes = tit[(tit['Sobreviveu'] == 'Sim')]

sobreviventes_classe1_total = sobreviventes[(sobreviventes['Classe'] == 1)]["IdPassageiro"].count()
sobreviventes_classe2_total = sobreviventes[(sobreviventes['Classe'] == 2)]["IdPassageiro"].count()
sobreviventes_classe3_total = sobreviventes[(sobreviventes['Classe'] == 3)]["IdPassageiro"].count()

print(f" % Classe 1: {(sobreviventes_classe1_total*100)/len(sobreviventes)}\
\n % Classe 2: {(sobreviventes_classe2_total*100)/len(sobreviventes)}\
\n % Classe 3: {(sobreviventes_classe3_total*100)/len(sobreviventes)}")
# Out:
#  % Classe 1: 39.76608187134503
#  % Classe 2: 25.43859649122807
#  % Classe 3: 34.7953216374269

# %%
labels = 'Classe 1', 'Classe 2', 'Classe 3'
sizes = [sobreviventes_classe1_total, sobreviventes_classe2_total, sobreviventes_classe3_total]

fig, ax = plt.subplots()
ax.set_title('Porcentagem de\n sobreviventes\n por classe')
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f60ceda0af0>,
#   <matplotlib.patches.Wedge at 0x7f60cedddf00>,
#   <matplotlib.patches.Wedge at 0x7f60d18b2380>],
#  [Text(0.34759742562046436, 1.043635966083014, 'Classe 1'),
#   Text(-1.086614775833759, -0.17107989051828945, 'Classe 2'),
#   Text(0.5056815692248013, -0.9768757088526373, 'Classe 3')])

# %% [markdown]
# 18 - Crie um dataframe que demonstre a quantidade de sobreviventes e não sobreviventes, agrupados por sexo e classe.

# %%
pd.DataFrame(tit.groupby("Sobreviveu")[["Sexo", "Classe"]].value_counts())
# Out:
#                             0
# Sobreviveu Sexo   Classe
# Não        Homem  3       300
#                   2        91
#                   1        77
#            Mulher 3        72
#                   2         6
#                   1         3
# Sim        Mulher 1        91
#                   3        72
#                   2        70
#            Homem  3        47
#                   1        45
#                   2        17
